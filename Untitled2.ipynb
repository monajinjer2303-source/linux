# %% [markdown]
# <a href="https://colab.research.google.com/github/monajinjer2303-source/linux/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data/

# %% [markdown]
# #ls 명령어 설명
# ls (list segments) 명령어는 리눅스/유닉스 환경에서 디렉토리 내부의 파일과 하위 디렉토리 목록을 화면에 출력하는 핵심 명령어입니다.
# 기본적으로 현재 디렉토리의 내용을 보여주며, 다양한 옵션을 통해 상세 정보, 숨김 파일, 정렬 방식 등을 제어할 수 있습니다.
#
# #주요 ls 명령어 옵션
# *   ls -l: 상세 정보(권한, 소유자, 크기, 수정 시간)를 롱 포맷으로 표시.
# *   ls -a: 숨김 파일(.)을 포함한 모든 파일 표시.

# %%
# !uname -a
# Out:
# Linux 1c56f80fc167 6.6.113+ #1 SMP Mon Feb  2 12:27:57 UTC 2026 x86_64 x86_64 x86_64 GNU/Linux
